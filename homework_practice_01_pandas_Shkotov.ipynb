# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexey-Shkotov/ml-dl/blob/main/homework_practice_01_pandas_Shkotov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 19.09.2023
#
# Мягкий дедлайн: 23:59MSK 02.10.2023
#
# Жесткий дедлайн: 23:59MSK 06.10.2023

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки pandas и визуализации с помощью matplotlib. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после жёсткого дедлайна нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате homework-practice-01-pandas-Username.ipynb, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: xx.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2

# %% [markdown]
# Ячейка с неразмеченным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
# your code

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидете много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно =)

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в pandas — это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %%
# %pylab inline
import pandas as pd
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <span style="color:red">Перед выполнением задания необходимо ознакомиться с первым семинаром (seminars/sem01-pandas.ipynb) </span>.
#
# Это поможет вам получить общее понимание происходяшего и успешнее справиться с заданием.
#
# Также успешному выполнению способствует внимательное чтение текста задания от начала до конца.
#
# Удачи!

# %% [markdown]
# Скачаем подготовленные на семинаре данные:

# %%
# !wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
# !powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
# import wget
# wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки. Использование <code>vectorize</code> и  <code>apply</code>, <code>apply_along_axis</code> крайне нежелательно.

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
data = pd.read_excel('end_seminar.xlsx')
data
# Out:
#                   timestamp                                id  rating  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572
# ..                      ...                               ...     ...
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# 0       181.0    NaN                                         Язык SQL
# 1       181.0    NaN                Высокопроизводительные вычисления
# 2       185.0    NaN                 Безопасность компьютерных систем
# 3       182.0    NaN                      Statistical Learning Theory
# 4       183.0    NaN                Высокопроизводительные вычисления
# ..        ...    ...                                              ...
# 356       NaN    NaN                      Statistical Learning Theory
# 357       NaN    NaN                Анализ неструктурированных данных
# 358       NaN    NaN  Сбор и обработка данных с помощью краудсорсинга
# 359       NaN    NaN                 Безопасность компьютерных систем
# 360       NaN    NaN                Анализ неструктурированных данных
#
#                                                 fall_2  \
# 0                    Высокопроизводительные вычисления
# 1                     Безопасность компьютерных систем
# 2                                 Матричные вычисления
# 3                    Высокопроизводительные вычисления
# 4                     Безопасность компьютерных систем
# ..                                                 ...
# 356                  Анализ неструктурированных данных
# 357                  Высокопроизводительные вычисления
# 358                        Statistical Learning Theory
# 359  Принятие решений в условиях риска и неопределё...
# 360                      Моделирование временных рядов
#
#                                               fall_3  \
# 0                               Матричные вычисления
# 1                                           Язык SQL
# 2                      Моделирование временных рядов
# 3                               Матричные вычисления
# 4                                  Теория баз данных
# ..                                               ...
# 356  Сбор и обработка данных с помощью краудсорсинга
# 357                    Моделирование временных рядов
# 358                Анализ неструктурированных данных
# 359                Анализ неструктурированных данных
# 360                Высокопроизводительные вычисления
#
#                                               spring_1  \
# 0                               Дискретная оптимизация
# 1                               Дискретная оптимизация
# 2                               Дискретная оптимизация
# 3                               Дискретная оптимизация
# 4                                    Компьютерные сети
# ..                                                 ...
# 356                           Обучение с подкреплением
# 357                             Конфликты и кооперация
# 358  Проектирование и разработка высоконагруженных ...
# 359  Проектирование и разработка высоконагруженных ...
# 360                           Обучение с подкреплением
#
#                                  spring_2  \
# 0                        Численные методы
# 1                        Численные методы
# 2                     Машинное обучение 2
# 3                        Численные методы
# 4                  Дискретная оптимизация
# ..                                    ...
# 356                Конфликты и кооперация
# 357              Обучение с подкреплением
# 358  Методы сжатия и передачи медиаданных
# 359  Методы сжатия и передачи медиаданных
# 360                   Компьютерное зрение
#
#                                  spring_3 is_first_time  percentile  17_group  \
# 0                     Машинное обучение 2            Да    0.183857       NaN
# 1                     Машинное обучение 2           Нет    0.426009       NaN
# 2                        Численные методы            Да    0.538117       NaN
# 3                     Машинное обучение 2            Да    0.744395       NaN
# 4                        Численные методы            Да    0.780269       NaN
# ..                                    ...           ...         ...       ...
# 356                   Компьютерное зрение            Да    0.920290     174.0
# 357                      Численные методы            Да    0.840580     174.0
# 358                      Численные методы            Да    0.652174     173.0
# 359                   Компьютерное зрение            Да    0.985507     172.0
# 360  Методы сжатия и передачи медиаданных           NaN    0.369565     176.0
#
#                             blended  is_ml_student
# 0                               NaN            NaN
# 1                               NaN            NaN
# 2                               NaN            NaN
# 3                               NaN            NaN
# 4                               NaN            NaN
# ..                              ...            ...
# 356                          DevOps            NaN
# 357                          DevOps            NaN
# 358  Соревновательный анализ данных            NaN
# 359                          DevOps            NaN
# 360  Соревновательный анализ данных            NaN
#
# [361 rows x 16 columns]

# %% [markdown]
# #### 2. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
data.isna().sum()
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %%
data.describe()
# Out:
#                            timestamp       rating    18_group  is_mi  \
# count                            361   361.000000  223.000000   18.0
# mean   2020-05-18 05:47:44.605210368   833.346260  184.520179    1.0
# min       2020-05-14 20:23:21.662000   495.000000  181.000000    1.0
# 25%    2020-05-17 17:40:31.867000064   613.000000  183.000000    1.0
# 50%    2020-05-18 19:23:38.273999872   697.000000  185.000000    1.0
# 75%       2020-05-18 22:24:55.160000  1111.000000  187.000000    1.0
# max       2020-05-24 01:23:31.946000  1457.000000  188.000000    1.0
# std                              NaN   266.665103    2.271701    0.0
#
#        percentile    17_group  is_ml_student
# count  361.000000  138.000000           57.0
# mean     0.497230  173.355072            1.0
# min      0.000000  171.000000            1.0
# 25%      0.246637  172.000000            1.0
# 50%      0.497758  173.000000            1.0
# 75%      0.746377  175.000000            1.0
# max      0.995516  177.000000            1.0
# std      0.289071    1.795374            0.0

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых (постарайтесь избежать перечисления названий всех столбцов).

# %%
def replace_nan(column):
    if column.dtype == 'object':
        return column.fillna('')
    elif np.issubdtype(column.dtype, np.number):
        return column.fillna(0)
    else:
        return column


data = data.apply(replace_nan)
data
# Out:
#                   timestamp                                id  rating  \
# 223 2020-05-14 20:23:21.662  d555d2805e1d93d4f023e57dc4c8f403     996
# 224 2020-05-14 20:47:13.833  253bbe1a2021d0404712a1e4acd22939    1106
# 225 2020-05-14 20:52:42.734  881b1a6fda195b354ae2edb396a69f5d    1084
# 226 2020-05-14 21:03:02.916  5a9b8ac11ad05b39a58b0e04a263bf4c    1170
# 227 2020-05-14 21:10:54.945  1bbbfae51794b83c769b634be8da7b8d    1078
# ..                      ...                               ...     ...
# 220 2020-05-21 16:33:15.899  1341f488fae5f1ccf164960fd6506cd0     584
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 221 2020-05-24 01:21:31.946  04bcb5c9d23813ffa940e1febb27fadc     646
# 222 2020-05-24 01:23:31.946  9d19b0d5f4fc8d7edc2258406f872c4e     695
#
#      18_group  is_mi                                fall_1  \
# 223       0.0    0.0      Безопасность компьютерных систем
# 224       0.0    0.0      Безопасность компьютерных систем
# 225       0.0    0.0      Безопасность компьютерных систем
# 226       0.0    0.0  Глубинное обучение в обработке звука
# 227       0.0    0.0      Безопасность компьютерных систем
# ..        ...    ...                                   ...
# 220     188.0    0.0                              Язык SQL
# 360       0.0    0.0     Анализ неструктурированных данных
# 359       0.0    0.0      Безопасность компьютерных систем
# 221     186.0    0.0                     Теория баз данных
# 222     188.0    0.0      Безопасность компьютерных систем
#
#                                                 fall_2  \
# 223               Глубинное обучение в обработке звука
# 224                      Моделирование временных рядов
# 225                  Анализ неструктурированных данных
# 226                        Statistical Learning Theory
# 227                  Высокопроизводительные вычисления
# ..                                                 ...
# 220                                  Теория баз данных
# 360                      Моделирование временных рядов
# 359  Принятие решений в условиях риска и неопределё...
# 221                  Высокопроизводительные вычисления
# 222                                           Язык SQL
#
#                                               fall_3  \
# 223            Байесовские методы машинного обучения
# 224                      Statistical Learning Theory
# 225             Глубинное обучение в обработке звука
# 226  Сбор и обработка данных с помощью краудсорсинга
# 227                Анализ неструктурированных данных
# ..                                               ...
# 220                 Безопасность компьютерных систем
# 360                Высокопроизводительные вычисления
# 359                Анализ неструктурированных данных
# 221                 Безопасность компьютерных систем
# 222                Высокопроизводительные вычисления
#
#                                               spring_1  \
# 223                                Компьютерное зрение
# 224  Проектирование и разработка высоконагруженных ...
# 225                                Компьютерное зрение
# 226                             Конфликты и кооперация
# 227  Проектирование и разработка высоконагруженных ...
# ..                                                 ...
# 220        Промышленное программирование на языке Java
# 360                           Обучение с подкреплением
# 359  Проектирование и разработка высоконагруженных ...
# 221                                  Компьютерные сети
# 222                                  Компьютерные сети
#
#                                               spring_2  \
# 223                           Обучение с подкреплением
# 224                                   Численные методы
# 225  Проектирование и разработка высоконагруженных ...
# 226                           Обучение с подкреплением
# 227               Методы сжатия и передачи медиаданных
# ..                                                 ...
# 220                                  Компьютерные сети
# 360                                Компьютерное зрение
# 359               Методы сжатия и передачи медиаданных
# 221                             Дискретная оптимизация
# 222                             Дискретная оптимизация
#
#                                               spring_3 is_first_time  \
# 223  Проектирование и разработка высоконагруженных ...            Да
# 224               Методы сжатия и передачи медиаданных            Да
# 225            Генеративные модели в машинном обучении            Да
# 226            Генеративные модели в машинном обучении            Да
# 227                             Конфликты и кооперация            Да
# ..                                                 ...           ...
# 220                                 Системы баз данных            Да
# 360               Методы сжатия и передачи медиаданных
# 359                                Компьютерное зрение            Да
# 221                                Машинное обучение 2           Нет
# 222                                   Численные методы
#
#      percentile  17_group                         blended  is_ml_student
# 223    0.963768     172.0                          DevOps            0.0
# 224    0.673913     176.0                          DevOps            0.0
# 225    0.782609     172.0                          DevOps            0.0
# 226    0.442029     171.0                          DevOps            0.0
# 227    0.789855     176.0                          DevOps            0.0
# ..          ...       ...                             ...            ...
# 220    0.721973       0.0                                            0.0
# 360    0.369565     176.0  Соревновательный анализ данных            0.0
# 359    0.985507     172.0                          DevOps            0.0
# 221    0.430493       0.0                                            0.0
# 222    0.197309       0.0                                            0.0
#
# [347 rows x 16 columns]

# %% [markdown]
# #### 3. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Есть ли в ней ответы "Нет"? Сколько их?
#
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию. В дальнейших заданиях используйте версию данных без повторов.
#
# <i>Обращения со значением "Нет" в 'is_first_time' могут быть как повторными, так и первичными, поскольку поле заполняли сами студенты.</i>

# %%
print('Повторных объектов:',data[data['is_first_time']== "Нет"].shape[0])
# Out:
# Повторных объектов: 51

# %%
data = data.sort_values(by='timestamp').drop_duplicates(subset=['id'], keep='last')

# %% [markdown]
# #### 4. [0.5 балла] Ответьте на вопросы:
# 1. Сколько было заявок из групп 18-го года набора, а сколько из групп 17-го года?
# 2. Есть ли студенты с равными перцентилями (среди объединенных данных, ведь конкурс на каждый курс общий)?

# %%
print('1.1 Заявок 18-го года:', data[data['18_group']>0].shape[0])
print('1.2 Заявок 17-го года:', data[data['17_group']>0].shape[0])
print("2   Студентов, имеющие равные перцентили:", data["percentile"].count() - data["percentile"].nunique()+1) #+1 из-за метода nunique()
# Out:
# 1.1 Заявок 18-го года: 213
# 1.2 Заявок 17-го года: 134
# 2   Студентов, имеющие равные перцентили: 2

# %% [markdown]
# #### 5. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из blended-курсов собрались студенты с самым высоким средним рейтингом (выведите этот курс и количество студентов на нем)?

# %%
data[data["17_group"] > 0]['blended'].describe()
# Out:
# count        134
# unique         3
# top       DevOps
# freq          87
# Name: blended, dtype: object

# %%
print("5.1 blended-курсы:", *data[data["17_group"] > 0]['blended'].unique(),sep='\n    ')
print('5.2 Самый популярный курс: DevOps') #из метода describe
mcc = data[data["17_group"] > 0].groupby(['blended'])['rating'].mean().idxmax() # most common course
print("5.3 Курс, где собрались студенты с самым высоким средним рейтингом:", mcc)
print("5.4 Кол-во студентов на нем:", data[(data["17_group"] > 0) & (data['blended'] == mcc)].shape[0])
# Out:
# 5.1 blended-курсы:
#     DevOps
#     Введение в дифференциальную геометрию
#     Соревновательный анализ данных
# 5.2 Самый популярный курс: DevOps
# 5.3 Курс, где собрались студенты с самым высоким средним рейтингом: Введение в дифференциальную геометрию
# 5.4 Кол-во студентов на нем: 15

# %% [markdown]
# #### 6. [1 балл] Выясните, есть ли студенты с абсолютно одинаковыми предпочтениями по всем курсам.
#
# Для этого сформируйте таблицу, где для каждого возможного набора курсов посчитано количество студентов, выбравших такой набор, и оставьте только строки где это количество больше 1.
#
# В данном случае набор курсов задается упорядоченным множеством ('fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'). Элемент blended будет нулевым для 3-го курса.

# %%
table_courses = data[['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']].groupby(['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']).size().reset_index().rename(columns={0:'count'})
table_courses[table_courses['count'] > 1]
# Out:
#                                               fall_1  \
# 0                        Statistical Learning Theory
# 60             Байесовские методы машинного обучения
# 62             Байесовские методы машинного обучения
# 72                  Безопасность компьютерных систем
# 84                  Безопасность компьютерных систем
# 102                 Безопасность компьютерных систем
# 105                 Безопасность компьютерных систем
# 113                 Безопасность компьютерных систем
# 137                 Безопасность компьютерных систем
# 155                 Безопасность компьютерных систем
# 184                Высокопроизводительные вычисления
# 201                Высокопроизводительные вычисления
# 244                    Моделирование временных рядов
# 292  Сбор и обработка данных с помощью краудсорсинга
# 313                                         Язык SQL
#
#                                               fall_2  \
# 0                  Анализ неструктурированных данных
# 60                 Анализ неструктурированных данных
# 62                 Анализ неструктурированных данных
# 72                       Statistical Learning Theory
# 84                 Высокопроизводительные вычисления
# 102                Высокопроизводительные вычисления
# 105                Высокопроизводительные вычисления
# 113                             Матричные вычисления
# 137  Сбор и обработка данных с помощью краудсорсинга
# 155                                Теория баз данных
# 184                 Безопасность компьютерных систем
# 201  Сбор и обработка данных с помощью краудсорсинга
# 244  Сбор и обработка данных с помощью краудсорсинга
# 292                                         Язык SQL
# 313                Высокопроизводительные вычисления
#
#                                               fall_3  \
# 0    Сбор и обработка данных с помощью краудсорсинга
# 60              Глубинное обучение в обработке звука
# 62   Сбор и обработка данных с помощью краудсорсинга
# 72                              Матричные вычисления
# 84                 Анализ неструктурированных данных
# 102                                         Язык SQL
# 105                                         Язык SQL
# 113                    Моделирование временных рядов
# 137                             Матричные вычисления
# 155                                         Язык SQL
# 184  Сбор и обработка данных с помощью краудсорсинга
# 201                    Моделирование временных рядов
# 244                 Безопасность компьютерных систем
# 292                                Теория баз данных
# 313                                Теория баз данных
#
#                                               spring_1  \
# 0                             Обучение с подкреплением
# 60                            Обучение с подкреплением
# 62                            Обучение с подкреплением
# 72                              Дискретная оптимизация
# 84   Проектирование и разработка высоконагруженных ...
# 102                                  Компьютерные сети
# 105        Промышленное программирование на языке Java
# 113        Промышленное программирование на языке Java
# 137                                  Компьютерные сети
# 155                                Машинное обучение 2
# 184  Проектирование и разработка высоконагруженных ...
# 201  Проектирование и разработка высоконагруженных ...
# 244                                  Компьютерные сети
# 292        Промышленное программирование на языке Java
# 313                                  Компьютерные сети
#
#                                         spring_2  \
# 0                         Конфликты и кооперация
# 60       Генеративные модели в машинном обучении
# 62                           Компьютерное зрение
# 72   Промышленное программирование на языке Java
# 84          Методы сжатия и передачи медиаданных
# 102  Промышленное программирование на языке Java
# 105                            Компьютерные сети
# 113                            Компьютерные сети
# 137  Промышленное программирование на языке Java
# 155                            Компьютерные сети
# 184         Методы сжатия и передачи медиаданных
# 201         Методы сжатия и передачи медиаданных
# 244   Дополнительные главы прикладной статистики
# 292                          Машинное обучение 2
# 313  Промышленное программирование на языке Java
#
#                                         spring_3 blended  count
# 0                            Компьютерное зрение  DevOps      2
# 60                           Компьютерное зрение  DevOps      2
# 62       Генеративные модели в машинном обучении  DevOps      2
# 72    Дополнительные главы прикладной статистики              3
# 84                        Конфликты и кооперация  DevOps      2
# 102                       Дискретная оптимизация              3
# 105                           Системы баз данных              2
# 113                       Дискретная оптимизация              2
# 137                      Анализ данных в бизнесе              2
# 155  Промышленное программирование на языке Java              2
# 184                          Компьютерное зрение  DevOps      2
# 201         Методы сжатия и передачи медиаданных  DevOps      2
# 244                           Системы баз данных              2
# 292                            Компьютерные сети              2
# 313                       Дискретная оптимизация              2

# %% [markdown]
# #### 7. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
year_17_courses = set(data.groupby(['18_group'])[['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']].apply(lambda x: list(np.unique(x)))[0])
year_18_courses = set(data.groupby(['17_group'])[['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']].apply(lambda x: list(np.unique(x)))[0][1:])

print("Записывались как студенты 18-го года набора, так и студенты 17-го года:")
print(*(year_17_courses & year_18_courses), sep=', ')
# Out:
# Записывались как студенты 18-го года набора, так и студенты 17-го года:
# Моделирование временных рядов, Принятие решений в условиях риска и неопределённости, Численные методы, Сбор и обработка данных с помощью краудсорсинга, Безопасность компьютерных систем, Statistical Learning Theory, Высокопроизводительные вычисления

# %%
print("Только студентам 18-го года:")
print(*(year_18_courses - year_17_courses), sep=', ')
print()
print("Только студентам 17-го года:")
print(*(year_17_courses - year_18_courses), sep=', ')
# Out:
# Только студентам 18-го года:
# Системы баз данных, Машинное обучение 2, Промышленное программирование на языке Java, Матричные вычисления, Дискретная оптимизация, Язык SQL, Теория баз данных, Дополнительные главы прикладной статистики, Анализ данных в бизнесе, Компьютерные сети
#
# Только студентам 17-го года:
# Глубинное обучение в обработке звука, Символьные вычисления, Соревновательный анализ данных, Введение в дифференциальную геометрию, DevOps, Компьютерное зрение, Методы сжатия и передачи медиаданных, Конфликты и кооперация, Генеративные модели в машинном обучении, Проектирование и разработка высоконагруженных сервисов, Байесовские методы машинного обучения, Обучение с подкреплением, Анализ неструктурированных данных

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.
#
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html) (обычно сокращается до sns). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
#
# **5 пунктов после которых ваши графики не будут прежними:**
# - для красивой картинки <code>%config InlineBackend.figure_format = 'retina'</code>
# - задаем размер (почти) всех графиков (можно выбрать другие значения) <code>plt.rcParams['figure.figsize'] = 8, 5</code>
# - размер шрифта подписей графиков <code>plt.rcParams['font.size'] = 12</code>
# - формат в котором сохраняется изображение <code>mpl.rcParams['savefig.format'] = 'pdf'</code>
# - sns – seaborn, добавляет решетку <code>sns.set_style('darkgrid')</code>
#
# Добавьте эти функции в ячейку ниже. Каждый график все равно придется настраивать отдельно, но указанные строчки позволят значительно упростить процесс.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 8, 5
plt.rcParams['font.size'] = 12
mpl.rcParams['savefig.format'] = 'pdf'
sns.set_style('darkgrid')

# %% [markdown]
# #### 8. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
data2 = data.copy()
data2['timestamp'] = data2['timestamp'].apply(lambda x: x.date())
data2.groupby('timestamp')['rating'].mean().plot.bar()
plt.xlabel("Дни")
plt.ylabel("Средний рейтинг")
plt.title("График средних рейтингов по дням")
plt.savefig("rating_by_day.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# <span style="color:red">!!!ВНИМАТЕЛЬНО ИЗУЧИТЕ ТЕКСТ НИЖЕ!!!</span>.
#
# <span style="color:orange">Если во время выполнения заданий у вас вознинут вопросы -- еще раз перечитайте текст целиком, скорее всего ответы уже содержатся в нем.</span>

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# Алгоритм распределения студентов по курсам:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом и еще не прошел на необходимое количество курсов. Места заполняются лучшими по перцентилю рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# Обращаем ваше внимание на следующие детали:
# - Конкурс на каждый курс общий для 3-го и 4-го курса
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса. <i>Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — <code>fall_1</code> и <code>fall_2</code>, второй приоритет — <code>fall_3</code>. Такие студенты участвуют только в двух волнах отбора</i>.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2. **Если студент специализации МОП выбрал Машинное обучение 2, то его приоритеты сдвигаются.** Из-за совпадений первого и второго курса по выбору двигать приоритеты не надо.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Заведомо известно, что в процессе распределения не возникнет ситуации, когда на одно место претендуют студенты с одинаковым перцентилем.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно. <i>Допустимо итерироваться по <b>курсам</b>, на которые проводится отбор, и по <b>волнам</b> отбора. Если вы придумаете, как обойтись и без этих циклов, то на усмотрение проверяющего могут быть добавлены бонусные баллы. <b>Дублирование кода не признается успешным избавлением от циклов</b></i>
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * Три колонки: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Если студент должен выбрать два курса по выбору, то порядок в колонках course1 и course2 не важен.
#
#     * hint: для сохранения воспользуйтесь df.to_csv('solution.csv', index=None)
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * У студентов 18-го года номера групп соответствуют номерам до распределения по специализациям. Это означает, что по номеру группы 18* нельзя однозначно определить специализацию студента. При этом в рамках распределения важно знать информацию только о двух из них: МОП и МИ. Эти знание можно получить из колонок 'is_ml_student
# ' и 'is_mi' соответственно.
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
assert data.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert data.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
num_to_spec = {171: "МОП",172: "МОП",173: "ТИ",174: "АДИС",175: "РС",176: "РС",177: "АПР"}
def get_fall_q(student):
    if student['17_group'] > 0:
        if num_to_spec[student['17_group']] in ['МОП', 'ТИ']:
            return 2
        else:
            return 1
    else:
        if student['is_mi']:
            return 2
        else:
            return 1
data['fall_q'] = data.apply(lambda student: get_fall_q(student), axis=1)

# %% [markdown]
# Проверка:

# %%
col_name =  'fall_q'   # insert your new column name as str

assert(data[data['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert(data[data['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert(data[data['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert(data[data['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
exception_places = {"Statistical Learning Theory": 60, "Высокопроизводительные вычисления": 60,"Анализ неструктурированных данных": 1e3,"Обучение с подкреплением": 60,"Анализ данных в бизнесе": 60,}
df = data.copy() # изначально другое название было, лень везде менять его
for k in ['is_first_place', 'is_last_place', 'course2', 'course1']:
    df[k] = np.nan
fall_courses = df[['fall_1', 'fall_2', 'fall_3']].apply(lambda x: list(np.unique(x)))
fall_courses_list = list(set(list(fall_courses['fall_1']) + list(fall_courses['fall_2']) + list(fall_courses['fall_3'])))
fall_places = dict.fromkeys(fall_courses_list, 30)
fall_places = {k: exception_places.get(k, v) for k, v in fall_places.items()}
df.loc[df['fall_q'] < 2, 'course2'] = '-'

for course in fall_courses_list:
    if not fall_places[course]: continue
    course_df = df[((df['fall_q'] > 1) & (df['fall_2'] == course)) | (course == df['fall_1'])].reset_index(drop=True)
    if not course_df.shape[0]: continue
    sorted_df = course_df.sort_values(by=['percentile']).reset_index().loc[:fall_places[course] - 1]
    fall_places[course] -= sorted_df.shape[0] # .shape[0]
    df.loc[df['course1'].isnull() & df['id'].isin(sorted_df['id']), 'course1'] = course
    df.loc[(df['id'].isin(sorted_df['id'])) & (df['fall_q'] > 1) & df['course1'].notnull() & (df['course1'] != course) & df['course2'].isnull(), 'course2'] = course
    df.loc[df['id'] == sorted_df['id'].values[0], 'is_first_place'] = True
    df.loc[df['id'] == sorted_df['id'].values[-1], 'is_last_place'] = True
# Out:
# <ipython-input-96-df27a3f9614d>:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['fall_q'] < 2, 'course2'] = '-'
# <ipython-input-96-df27a3f9614d>:17: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Глубинное обучение в обработке звука' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['course1'].isnull() & df['id'].isin(sorted_df['id']), 'course1'] = course
# <ipython-input-96-df27a3f9614d>:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['id'] == sorted_df['id'].values[0], 'is_first_place'] = True
# <ipython-input-96-df27a3f9614d>:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['id'] == sorted_df['id'].values[-1], 'is_last_place'] = True

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
# !wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0'
check_df = pd.read_csv('2_task_check.csv')

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
fir_col_name = 'is_first_place'
last_col_name = 'is_last_place'

assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ==
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()

# %% [markdown]
# #### 3. [3 балла] Проведите все три волны отбора студентов на курсы по выбору

# %%
print(fall_places)
for course in fall_courses_list:
    if not fall_places[course]: continue
    course_df = df[((df['fall_q'] == 1) & (df['fall_2'] == course) & df['course1'].isnull()) | ((df['fall_q'] == 2) & (df['course1'].isnull() | df['course2'].isnull()) & (df['fall_3'] == course)) & (df['course1'] != course) & (df['course2'] != course)].reset_index(drop=True)
    if not course_df.shape[0]: continue
    sorted_df = course_df.sort_values(by=['percentile']).reset_index().loc[:fall_places[course] - 1]
    fall_places[course] -= len(sorted_df) # .shape[0]
    df.loc[(df['course1'].isnull()) & df['id'].isin(sorted_df['id']), 'course1'] = course
    df.loc[(df['fall_q'] > 1) & df['course2'].isnull() & (df['course1'] != course) & df['id'].isin(sorted_df['id']), 'course2'] = course

print(fall_places)

for course in fall_courses_list:
    if not fall_places[course]: continue
    course_df = df[(df['fall_q'] == 1) & (df['fall_3'] == course) & df['course1'].isnull()].reset_index(drop=True) # & df['course1'].isnull()
    if not course_df.shape[0]: continue
    sorted_df = course_df.sort_values(by=['percentile']).reset_index().loc[:fall_places[course] - 1]
    df.loc[df['id'].isin(sorted_df['id']), 'course1'] = course

df.loc[df['course2'].isnull(), 'course2'] = '???'
df.loc[df['course1'].isnull(), 'course1'] = '???'
res_fall = {
    'ID': df['id'],
    'course1': df['course1'],
    'course2': df['course2']
}
res_fall = pd.DataFrame.from_dict(res_fall)
res_fall
# Out:
# {'Глубинное обучение в обработке звука': 0, 'Моделирование временных рядов': 0, 'Матричные вычисления': 6, 'Принятие решений в условиях риска и неопределённости': 21, 'Язык SQL': 0, 'Сбор и обработка данных с помощью краудсорсинга': 0, 'Теория баз данных': 12, 'Безопасность компьютерных систем': 0, 'Statistical Learning Theory': 19, 'Байесовские методы машинного обучения': 5, 'Высокопроизводительные вычисления': 0, 'Анализ неструктурированных данных': 947.0}
# {'Глубинное обучение в обработке звука': 0, 'Моделирование временных рядов': 0, 'Матричные вычисления': 6, 'Принятие решений в условиях риска и неопределённости': 21, 'Язык SQL': 0, 'Сбор и обработка данных с помощью краудсорсинга': 0, 'Теория баз данных': 12, 'Безопасность компьютерных систем': 0, 'Statistical Learning Theory': 19, 'Байесовские методы машинного обучения': 5, 'Высокопроизводительные вычисления': 0, 'Анализ неструктурированных данных': 947.0}
#                                    ID  \
# 223  d555d2805e1d93d4f023e57dc4c8f403
# 224  253bbe1a2021d0404712a1e4acd22939
# 225  881b1a6fda195b354ae2edb396a69f5d
# 226  5a9b8ac11ad05b39a58b0e04a263bf4c
# 227  1bbbfae51794b83c769b634be8da7b8d
# ..                                ...
# 220  1341f488fae5f1ccf164960fd6506cd0
# 360  f2d210ace25a841e1e58036b257d5d47
# 359  79d14db48e4737af731960ae212d5134
# 221  04bcb5c9d23813ffa940e1febb27fadc
# 222  9d19b0d5f4fc8d7edc2258406f872c4e
#
#                                                course1  \
# 223               Глубинное обучение в обработке звука
# 224                        Statistical Learning Theory
# 225                  Анализ неструктурированных данных
# 226               Глубинное обучение в обработке звука
# 227                  Анализ неструктурированных данных
# ..                                                 ...
# 220                                           Язык SQL
# 360                  Анализ неструктурированных данных
# 359  Принятие решений в условиях риска и неопределё...
# 221                                  Теория баз данных
# 222                   Безопасность компьютерных систем
#
#                                    course2
# 223  Байесовские методы машинного обучения
# 224                                      -
# 225   Глубинное обучение в обработке звука
# 226            Statistical Learning Theory
# 227                                      -
# ..                                     ...
# 220                                      -
# 360                                      -
# 359      Анализ неструктурированных данных
# 221                                      -
# 222                                      -
#
# [347 rows x 3 columns]

# %%
res_fall.to_csv('res_fall.csv', index=None)

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (https://contest.yandex.ru/contest/52663/problems/A/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# *Дисклеймер:*
#
# Успешная посылка в контесте является **обязательным** условием получения полного балла за этот (и следующий) пункт. Если добиться успешной посылки не удастся, баллы будут выставляться на усмотрение проверяюшего.
#
# При этом ОК в контесте не гарантирует полный балл. Оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# **Дополнительное задание. [2 бонусных балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.**
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %%
def get_spring_q(student):
    if student['17_group'] > 0:
        if num_to_spec[student['17_group']] in ['МОП', 'ТИ']:
            return 2
        else:
            return 1
    else:
        return 1
df['spring_q'] = data.apply(lambda student: get_spring_q(student), axis=1)

# %%
is_mop = (((df['17_group'] > 0) & (df['17_group'] <= 172)) | ((df['18_group'] > 0) & (df['is_ml_student'] == 1)))
df.loc[is_mop & (df['spring_1'] == 'Машинное обучение 2'), ['spring_1', 'spring_2', 'spring_3']] = df.loc[is_mop & (df['spring_1'] == 'Машинное обучение 2'), ['spring_2', 'spring_3', 'spring_1']].values
df.loc[is_mop & (df['spring_2'] == 'Машинное обучение 2'), ['spring_1', 'spring_2', 'spring_3']] = df.loc[is_mop & (df['spring_2'] == 'Машинное обучение 2'), ['spring_1', 'spring_3', 'spring_2']].values

# %%
for k in ['course1_spring', 'course2_spring']:
    df[k] = np.nan
spring_courses = df[['spring_1', 'spring_2', 'spring_3']].apply(lambda x: list(np.unique(x)))
spring_courses_list = list(set(list(spring_courses['spring_1']) + list(spring_courses['spring_2']) + list(spring_courses['spring_3'])))
spring_places = dict.fromkeys(spring_courses_list, 30)
spring_places = {k: exception_places.get(k, v) for k, v in spring_places.items()}
df.loc[df['spring_q'] < 2, 'course2_spring'] = '-'

for course in spring_courses_list:
    if not spring_places[course]: continue
    course_df = df[((df['spring_q'] > 1) & (df['spring_2'] == course)) | (course == df['spring_1'])].reset_index(drop=True)
    if not course_df.shape[0]: continue
    sorted_df = course_df.sort_values(by=['percentile']).reset_index().loc[:spring_places[course] - 1]
    spring_places[course] -= sorted_df.shape[0] # .shape[0]
    df.loc[df['course1_spring'].isnull() & df['id'].isin(sorted_df['id']), 'course1_spring'] = course
    df.loc[(df['id'].isin(sorted_df['id'])) & (df['spring_q'] > 1) & df['course1_spring'].notnull() & (df['course1_spring'] != course) & df['course2_spring'].isnull(), 'course2_spring'] = course

for course in spring_courses_list:
    if not spring_places[course]: continue
    course_df = df[((df['spring_q'] == 1) & (df['spring_2'] == course) & df['course1_spring'].isnull()) | ((df['spring_q'] == 2) & (df['course1_spring'].isnull() | df['course2_spring'].isnull()) & (df['spring_3'] == course)) & (df['course1_spring'] != course) & (df['course2_spring'] != course)].reset_index(drop=True)
    if not course_df.shape[0]: continue
    sorted_df = course_df.sort_values(by=['percentile']).reset_index().loc[:spring_places[course] - 1]
    spring_places[course] -= len(sorted_df) # .shape[0]
    df.loc[(df['course1_spring'].isnull()) & df['id'].isin(sorted_df['id']), 'course1_spring'] = course
    df.loc[(df['spring_q'] > 1) & df['course2_spring'].isnull() & (df['course1_spring'] != course) & df['id'].isin(sorted_df['id']), 'course2_spring'] = course

for course in spring_courses_list:
    if not spring_places[course]: continue
    course_df = df[(df['spring_q'] == 1) & (df['spring_3'] == course) & df['course1_spring'].isnull()].reset_index(drop=True) # & df['course1'].isnull()
    if not course_df.shape[0]: continue
    sorted_df = course_df.sort_values(by=['percentile']).reset_index().loc[:spring_places[course] - 1]
    df.loc[df['id'].isin(sorted_df['id']), 'course1_spring'] = course

df.loc[df['course2_spring'].isnull(), 'course2_spring'] = '???'
df.loc[df['course1_spring'].isnull(), 'course1_spring'] = '???'
# Out:
# <ipython-input-104-78962ba67919>:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['spring_q'] < 2, 'course2_spring'] = '-'
# <ipython-input-104-78962ba67919>:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Системы баз данных' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['course1_spring'].isnull() & df['id'].isin(sorted_df['id']), 'course1_spring'] = course

# %%
res_spring = {
    'ID': df['id'],
    'course1': df['course1_spring'],
    'course2': df['course2_spring']
}
res_spring = pd.DataFrame.from_dict(res_spring)
res_spring
# Out:
#                                    ID                               course1  \
# 223  d555d2805e1d93d4f023e57dc4c8f403                   Компьютерное зрение
# 224  253bbe1a2021d0404712a1e4acd22939                      Численные методы
# 225  881b1a6fda195b354ae2edb396a69f5d                   Компьютерное зрение
# 226  5a9b8ac11ad05b39a58b0e04a263bf4c                Конфликты и кооперация
# 227  1bbbfae51794b83c769b634be8da7b8d  Методы сжатия и передачи медиаданных
# ..                                ...                                   ...
# 220  1341f488fae5f1ccf164960fd6506cd0                    Системы баз данных
# 360  f2d210ace25a841e1e58036b257d5d47              Обучение с подкреплением
# 359  79d14db48e4737af731960ae212d5134  Методы сжатия и передачи медиаданных
# 221  04bcb5c9d23813ffa940e1febb27fadc                     Компьютерные сети
# 222  9d19b0d5f4fc8d7edc2258406f872c4e                     Компьютерные сети
#
#                                      course2
# 223                 Обучение с подкреплением
# 224                                        -
# 225  Генеративные модели в машинном обучении
# 226                 Обучение с подкреплением
# 227                                        -
# ..                                       ...
# 220                                        -
# 360                                        -
# 359                                      ???
# 221                                        -
# 222                                        -
#
# [347 rows x 3 columns]

# %%
res_spring.to_csv('res_spring.csv', index=None)

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (https://contest.yandex.ru/contest/52663/problems/A) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:

# %%
from PIL import Image
# !wget https://cdn.iportal.ru/preview/e1forum/photo/1a4ecd93e52168321266e3ee15ef0ddd09fa2bc0_700_700.jpg
image = Image.open('1a4ecd93e52168321266e3ee15ef0ddd09fa2bc0_700_700.jpg')
image
# Out:
# --2024-08-17 19:09:51--  https://cdn.iportal.ru/preview/e1forum/photo/1a4ecd93e52168321266e3ee15ef0ddd09fa2bc0_700_700.jpg
# Resolving cdn.iportal.ru (cdn.iportal.ru)... 185.40.155.13
# Connecting to cdn.iportal.ru (cdn.iportal.ru)|185.40.155.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81101 (79K) [image/jpeg]
# Saving to: ‘1a4ecd93e52168321266e3ee15ef0ddd09fa2bc0_700_700.jpg.1’
#
# 1a4ecd93e5216832126 100%[===================>]  79.20K   266KB/s    in 0.3s
#
# 2024-08-17 19:09:53 (266 KB/s) - ‘1a4ecd93e52168321266e3ee15ef0ddd09fa2bc0_700_700.jpg.1’ saved [81101/81101]
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x700>
